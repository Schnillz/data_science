# %% [markdown]
# ## Getting k

# %%
# %matplotlib inline
from copy import deepcopy
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.cluster import KMeans
plt.rcParams['figure.figsize'] = (16, 9)
# plt.style.use('ggplot')

# Importing the dataset
data = pd.read_csv('edlich-kmeans-A0.csv')
print(data.shape)
data.head()
# Out:
# (100, 3)
#          V1        V2        V3
# 0 -5.340236  4.747246  3.823326
# 1 -9.587065 -3.434466  9.701839
# 2 -8.385012 -3.902794  8.514620
# 3  5.708226  2.658575  5.404482
# 4 -7.431665 -4.390251  9.003216

# %%
f1 = data['V1'].values
f2 = data['V2'].values
f3 = data['V3'].values
X = np.array(list(zip(f1, f2, f3)))
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(X[:, 0], X[:,1], X[:,2])

# %% [markdown]
# ### k = 5

# %% [markdown]
# ## Getting kmeans

# %%
kmeans = KMeans(n_clusters=5)
kmeans = kmeans.fit(X)
labels = kmeans.predict(X)
C = kmeans.cluster_centers_

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(X[:, 0], X[:,1], X[:,2], c='#000000')
ax.scatter(C[:, 0], C[:,1], C[:,2], marker='*', c='#ffffff', s=1000)

# %%
# Euclidean Distance Caculator
def dist(a, b, ax=1):
    return np.linalg.norm(a - b, axis=ax)

# To store the value of centroids when it updates
C_old = np.zeros(C.shape)
# Cluster Lables(0, 1, 2)
clusters = np.zeros(len(X))
# Error func. - Distance between new centroids and old centroids
error = dist(C, C_old, None)
# Loop will run till the error becomes zero
while error != 0:
    # Assigning each value to its closest cluster
    for i in range(len(X)):
        distances = dist(X[i], C)
        cluster = np.argmin(distances)
        clusters[i] = cluster
    # Storing the old centroid values
    C_old = deepcopy(C)
    error = dist(C, C_old, None)

# %% [markdown]
# ### Print clustering vector

# %%
for i in range(len(clusters)):
    # str = 'Index: ' + i * 'belongs to cluster: ' + clusters[i] 
    print('Point ' + str(i) + ' belongs to Cluster: ' + str(clusters[i]) )
# Out:
# Point 0 belongs to Cluster: 2.0
# Point 1 belongs to Cluster: 4.0
# Point 2 belongs to Cluster: 4.0
# Point 3 belongs to Cluster: 0.0
# Point 4 belongs to Cluster: 4.0
# Point 5 belongs to Cluster: 3.0
# Point 6 belongs to Cluster: 0.0
# Point 7 belongs to Cluster: 4.0
# Point 8 belongs to Cluster: 1.0
# Point 9 belongs to Cluster: 0.0
# Point 10 belongs to Cluster: 4.0
# Point 11 belongs to Cluster: 1.0
# Point 12 belongs to Cluster: 0.0
# Point 13 belongs to Cluster: 3.0
# Point 14 belongs to Cluster: 2.0
# Point 15 belongs to Cluster: 4.0
# Point 16 belongs to Cluster: 1.0
# Point 17 belongs to Cluster: 3.0
# Point 18 belongs to Cluster: 2.0
# Point 19 belongs to Cluster: 2.0
# Point 20 belongs to Cluster: 4.0
# Point 21 belongs to Cluster: 1.0
# Point 22 belongs to Cluster: 2.0
# Point 23 belongs to Cluster: 4.0
# Point 24 belongs to Cluster: 4.0
# Point 25 belongs to Cluster: 0.0
# Point 26 belongs to Cluster: 1.0
# Point 27 belongs to Cluster: 1.0
# ...
